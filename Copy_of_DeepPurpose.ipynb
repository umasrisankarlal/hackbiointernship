# %% [markdown]
# <a href="https://colab.research.google.com/github/umasrisankarlal/hackbiointernship/blob/main/Copy_of_DeepPurpose.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INSTALLING ANACONDA

# %%
# !echo $PYTHONPATH
# Out:
# /env/python

# %%
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
# %%bash
# conda install --channel defaults conda python=3.6 --yes
# conda update --channel defaults --all --yes
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     tk-8.6.10                  |       hbc83047_0         3.2 MB
#     ruamel_yaml-0.15.100       |   py36h27cfd23_0         268 KB
#     pyopenssl-20.0.1           |     pyhd3eb1b0_1          48 KB
#     certifi-2021.5.30          |   py36h06a4308_0         141 KB
#     pip-21.2.2                 |   py36h06a4308_0         2.1 MB
#     sqlite-3.36.0              |       hc218d9a_0         1.4 MB
#     zlib-1.2.11                |       h7b6447c_3         120 KB
#     _libgcc_mutex-0.1          |             main           3 KB
#     ca-certificates-2021.7.5   |       h06a4308_1         119 KB
#     idna-2.10                  |     pyhd3eb1b0_0          52 KB
# ...

# %%
import sys
_ = (sys.path
        .append("/usr/local/lib/python3.6/site-packages"))

# %%
# !conda install --channel conda-forge featuretools --yes
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - featuretools
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bokeh-2.3.3                |   py36h5fab9bb_0         8.3 MB  conda-forge
#     ca-certificates-2021.5.30  |       ha878542_0         136 KB  conda-forge
#     certifi-2021.5.30          |   py36h5fab9bb_0         141 KB  conda-forge
#     click-7.1.2                |     pyh9f0ad1d_0          64 KB  conda-forge
#     cloudpickle-1.6.0          |             py_0          22 KB  conda-forge
#     conda-4.10.3               |   py36h5fab9bb_0         3.1 MB  conda-forge
# ...

# %% [markdown]
# #DeepPurpose

# %%
# !git clone https://github.com/kexinhuang12345/DeepPurpose.git
# Out:
# Cloning into 'DeepPurpose'...
# remote: Enumerating objects: 2911, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 2911 (delta 49), reused 43 (delta 22), pack-reused 2837
# Receiving objects: 100% (2911/2911), 14.79 MiB | 25.62 MiB/s, done.
# Resolving deltas: 100% (1856/1856), done.

# %%
# %%bash
# cd /content/DeepPurpose
# echo -y | conda env create -f environment.yml
# source activate DeepPurpose
#
#
# python play.py
#
# # play.py contain the following lines and is in DeepPurpose folder
#
# # from DeepPurpose import oneliner
# # from DeepPurpose.dataset import *
# # oneliner.repurpose(*load_SARS_CoV2_Protease_3CL(), *load_antiviral_drugs(no_cid = True))
# Out:
# ...
# Solving environment: ...working... done
#
# ...
# tk-8.6.8             | 3.1 MB    | ########## | 100%
# idna-2.9             | 52 KB     | ########## | 100%
# ipython-7.13.0       | 1.1 MB    | ########## | 100%
# six-1.14.0           | 13 KB     | ########## | 100%
# blinker-1.4          | 13 KB     | ########## | 100%
# cudatoolkit-10.1.243 | 427.5 MB  | ########## | 100%
# libffi-3.2.1         | 47 KB     | ########## | 100%
# zstd-1.3.7           | 905 KB    | ########## | 100%
# pycparser-2.20       | 94 KB     | ########## | 100%
# libtiff-4.1.0        | 447 KB    | ########## | 100%
# libuuid-2.32.1       | 28 KB     | ########## | 100%
# pthread-stubs-0.4    | 5 KB      | ########## | 100%
# mkl_fft-1.0.15       | 169 KB    | ########## | 100%
# seaborn-0.11.0       | 4 KB      | ########## | 100%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
# attrs-19.3.0         | 35 KB     | ########## | 100%
# requests-oauthlib-1. | 21 KB     | ########## | 100%
# ...
